# %%
Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Tapas Walde",
        "date_created":"2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Tapas Walde', 'date_created': '2025-01-01'}, page_content='this is the main text content I am using to create RAG')

# %%
#create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":
    """Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991.

Python is designed to be easy to learn and powerful enough for building everything from small scripts to large-scale applications.

🚀 Why Python is Popular

✅ Easy to read and write

✅ Beginner-friendly syntax

✅ Huge community support

✅ Works on Windows, Mac, Linux

✅ Massive library ecosystem

💡 Where Python is Used

🌐 Web development (e.g., Django, Flask)

🤖 Artificial Intelligence & Machine Learning

📊 Data Science & Analytics

🛠 Automation & Scripting

🧪 Scientific computing

🎮 Game development"""
}

sample_texts2={
    "../data/text_files/ML_intro.txt":"""Machine Learning (ML) is a branch of Artificial Intelligence where computers learn patterns from data and make predictions or decisions without being explicitly programmed.

Instead of writing rules manually, we train models using data.

🧠 Simple Definition

Machine Learning is the science of teaching computers to learn from data.

For example:

Spam email detection

Movie recommendations

Face recognition

Stock price prediction

🚀 Why ML is Popular

📊 Handles large amounts of data

🤖 Powers AI applications

💼 High industry demand

💰 Strong career opportunities

🌍 Used in almost every industry

📚 Types of Machine Learning
1️⃣ Supervised Learning

Learns from labeled data

Example: Email marked as spam/not spam

Algorithms:

Linear Regression

Logistic Regression

Decision Trees

2️⃣ Unsupervised Learning

No labeled data

Finds hidden patterns

Example:

Customer segmentation

Algorithms:

K-Means Clustering

PCA

3️⃣ Reinforcement Learning

Learns by trial and error

Used in robotics and games

Example:

Self-driving cars

Game-playing AI"""
}
for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8")as f:
        f.write(content)
for filepath,content in sample_texts2.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)
print("Sample text files created")
# Out:
# Sample text files created

# %%
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python is a high-level, interpreted programming language known for its simplicity and readability. It was created by Guido van Rossum and first released in 1991.\n\nPython is designed to be easy to learn and powerful enough for building everything from small scripts to large-scale applications.\n\n🚀 Why Python is Popular\n\n✅ Easy to read and write\n\n✅ Beginner-friendly syntax\n\n✅ Huge community support\n\n✅ Works on Windows, Mac, Linux\n\n✅ Massive library ecosystem\n\n💡 Where Python is Used\n\n🌐 Web development (e.g., Django, Flask)\n\n🤖 Artificial Intelligence & Machine Learning\n\n📊 Data Science & Analytics\n\n🛠 Automation & Scripting\n\n🧪 Scientific computing\n\n🎮 Game development')]

# %%
## Directory loader
from langchain_community.document_loaders import DirectoryLoader

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", #pattern to match files
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)
document=dir_loader.load()
document
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\ML_intro.txt'}, page_content='Machine Learning (ML) is a branch of Artificial Intelligence where computers learn patterns from data and make predictions or decisions without being explicitly programmed.\n\nInstead of writing rules manually, we train models using data.\n\n🧠 Simple Definition\n\nMachine Learning is the science of teaching computers to learn from data.\n\nFor example:\n\nSpam email detection\n\nMovie recommendations\n\nFace recognition\n\nStock price prediction\n\n🚀 Why ML is Popular\n\n📊 Handles large amounts of data\n\n🤖 Powers AI applications\n\n💼 High industry demand\n\n💰 Strong career opportunities\n\n🌍 Used in almost every industry\n\n📚 Types of Machine Learning\n1️⃣ Supervised Learning\n\nLearns from labeled data\n\nExample: Email marked as spam/not spam\n\nAlgorithms:\n\nLinear Regression\n\nLogistic Regression\n\nDecision Trees\n\n2️⃣ Unsupervised Learning\n\nNo labeled data\n\nFinds hidden patterns\n\nExampl
# ...

# %%
from langchain_community.document_loaders import (
    PyMuPDFLoader,
    DirectoryLoader
)

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", #pattern to match files
    loader_cls=PyMuPDFLoader,
    show_progress=False
)

pdf_document = dir_loader.load()

pdf_document
# Out:
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': '', 'creationdate': '2024-05-22T12:01:55+05:30', 'source': '..\\data\\pdf\\python cheatsheet.pdf', 'file_path': '..\\data\\pdf\\python cheatsheet.pdf', 'total_pages': 21, 'format': 'PDF 1.7', 'title': 'Python CheatSheet _ CodeWithHarry', 'author': 'Rohan Das', 'subject': '', 'keywords': '', 'moddate': '2024-05-22T12:01:55+05:30', 'trapped': '', 'modDate': "D:20240522120155+05'30'", 'creationDate': "D:20240522120155+05'30'", 'page': 0}, page_content=''),
# ...
